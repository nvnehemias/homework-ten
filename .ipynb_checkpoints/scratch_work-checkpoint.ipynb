# %%
#!pip install splinter

# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re

# %%
#https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
#executable_path = {'executable_path': '/Users/nehemias/Downloads/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL of page to be scraped
url_1 = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"

# %%
browser.visit(url_1)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
results = soup.find_all('div',class_ = "content_title")
list_title = []
for answer in results:
    list_title.append(answer.text)
news_title = list_title[0]
news_title
# Out:
# "What's Mars Solar Conjunction, and Why Does It Matter?"

# %%
results_2 = soup.find_all('div',class_ = "article_teaser_body")
new_list_title = []
for answer in results_2:
    new_list_title.append(answer.text)
news_p = new_list_title[0]
news_p
# Out:
# 'NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.'

# %%
url_2 = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"

# %%
browser.visit(url_2)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
new_result = soup.find_all('article')
split_url = new_result[0].attrs['style'][23:-3]

# %%
split_url
# Out:
# '/spaceimages/images/wallpaper/PIA16919-1920x1200.jpg'

# %%
featured_image_url = f"https://www.jpl.nasa.gov{split_url}"

# %%
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA16919-1920x1200.jpg'

# %%
url_3 = "https://twitter.com/marswxreport?lang=en"
browser.visit(url_3)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#results_3 = soup.find_all('span', class_ = "css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0")
results_3 = soup.find_all('p', class_ = "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text")
mars_weather = print(results_3[0].text[0:-26])
mars_weather
# Out:
# InSight sol 261 (2019-08-21) low -102.4ºC (-152.4ºF) high -26.6ºC (-15.8ºF)
# winds from the SSE at 4.9 m/s (11.0 mph) gusting to 16.0 m/s (35.8 mph)
# pressure at 7.70 hPa

# %%
[span.text for span in results_3 if span.text != '']
# Out:
# ['Home',
#  'Home',
#  'Home, current page.',
#  'Moments',
#  'Moments',
#  'Moments, current page.',
#  '\n\nSearch Twitter\n\n',
#  'Search Twitter',
#  'Remove',
#  'Remove',
#  'In this conversation',
#  '\nVerified accountProtected Tweets\xa0@\n',
#  'Verified accountProtected Tweets',
#  'Verified account',
#  'Verified account',
#  'Protected Tweets',
#  'Protected Tweets',
#  '\xa0',
#  '@',
#  'English',
#  ' ',
#  ' Log in',
#  'Remember me',
#  '·',
#  '@MarsWxReport',
#  'Tweets',
#  'Tweets, current page.',
#  '1,927\n            ',
#  'Following',
#  'Following',
#  '53',
#  'Followers',
#  'Followers',
#  '49.1K',
#  'Likes',
#  'Likes',
#  '305',
#  'Lists',
#  'Lists',
#  '9',
#  '\xa0',
#  'More ',
#  '\n\nUnmute @MarsWxReport\n\nMute @MarsWxReport\n',
#  'Unmute @MarsWxReport',
#  'Unmute @MarsWxReport',
#  '@MarsWxReport',
#  'Mute @MarsWxReport',
#  'Mute @MarsWxReport',
#  '@MarsWxReport',
#  '\n\nFollow\nFollow @MarsWxReport\n\n\nFollowing\nFollowing @MarsWxReport\n\n\nUnfollow\nUnfollow @MarsWxReport\n\n\nBlocked\nBlocked @MarsWxReport\n\n\nUnblock\nUnblock @MarsWxReport\n\n\nPending\nPending follow request from @MarsWxReport\n\n\nCancel\nCancel your follow request to @MarsWxReport\n\n',
#  'Follow',
#  'Follow @MarsWxReport',
#  '@MarsWxReport',
#  'Following',
#  'Following @MarsWxReport',
#  '@MarsWxReport',
#  'Unfollow',
#  'Unfollow @MarsWxReport',
#  '@MarsWxReport',
#  'Blocked',
#  'Blocked @MarsWxReport',
#  '@MarsWxReport',
#  'Unblock',
#  'Unblock @MarsWxReport',
#  '@MarsWxReport',
#  'Pending',
#  'Pending follow request from @MarsWxReport',
#  '@MarsWxReport',
#  'Cancel',
#  'Cancel your follow request to @MarsWxReport',
#  '@MarsWxReport',
#  '@MarsWxReport',
#  '\n              Gale Crater, Mars\n\n        ',
#  ' \n    mars.nasa.gov/news/8415/insi…\n  \n',
#  'Joined August 2012',
#  '\n',
#  '\n\n                \n                334 Photos and videos\n            \n\n            Photos and videos\n          \n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\nNASA InSightVerified account\xa0@NASAInSight\n',
#  'Verified account',
#  'Verified account',
#  'Verified account',
#  '\xa0',
#  '@NASAInSight',
#  '\nHiRISE (NASA)Verified account\xa0@HiRISE\n',
#  'Verified account',
#  'Verified account',
#  'Verified account',
#  '\xa0',
#  '@HiRISE',
#  '\nAndrew RaderVerified account\xa0@marsrader\n',
#  'Verified account',
#  'Verified account',
#  'Verified account',
#  '\xa0',
#  '@marsrader',
#  '\nnot available \xa0🐝\xa0@ThomasMoszczuk\n',
#  '\xa0',
#  '🐝',
#  '\xa0',
#  '@ThomasMoszczuk',
#  '\nBuzz AldrinVerified account\xa0@TheRealBuzz\n',
#  'Verified account',
#  'Verified account',
#  'Verified account',
#  '\xa0',
#  '@TheRealBuzz',
#  'Worldwide trends',
#  'James Charles',
#  'Arsenal',
#  '#taylurking',
#  'Liverpool',
#  'Emma Stone',
#  '#RuinASuperheroMovie',
#  'Kovalev',
#  'Code of Honor',
#  'Blair Walsh',
#  'Samford',
#  'Tweets',
#  'Tweets, current page.',
#  '@MarsWxReport',
#  '@MarsWxReport',
#  '\nClose\n',
#  'Close',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 22',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n18 likes\n\n',
#  '\n18 likes\n',
#  '18 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n18\n',
#  '18',
#  'Liked',
#  '\n18\n',
#  '18',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 22',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n4 retweets\n\n',
#  '\n4 retweets\n',
#  '4 retweets',
#  '\n\n14 likes\n\n',
#  '\n14 likes\n',
#  '14 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n4\n',
#  '4',
#  'Retweeted',
#  '\n4\n',
#  '4',
#  'Like',
#  '\n14\n',
#  '14',
#  'Liked',
#  '\n14\n',
#  '14',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 22',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n6 retweets\n\n',
#  '\n6 retweets\n',
#  '6 retweets',
#  '\n\n14 likes\n\n',
#  '\n14 likes\n',
#  '14 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n6\n',
#  '6',
#  'Retweeted',
#  '\n6\n',
#  '6',
#  'Like',
#  '\n14\n',
#  '14',
#  'Liked',
#  '\n14\n',
#  '14',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 19',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n8 retweets\n\n',
#  '\n8 retweets\n',
#  '8 retweets',
#  '\n\n13 likes\n\n',
#  '\n13 likes\n',
#  '13 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n8\n',
#  '8',
#  'Retweeted',
#  '\n8\n',
#  '8',
#  'Like',
#  '\n13\n',
#  '13',
#  'Liked',
#  '\n13\n',
#  '13',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 18',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n6 retweets\n\n',
#  '\n6 retweets\n',
#  '6 retweets',
#  '\n\n13 likes\n\n',
#  '\n13 likes\n',
#  '13 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n6\n',
#  '6',
#  'Retweeted',
#  '\n6\n',
#  '6',
#  'Like',
#  '\n13\n',
#  '13',
#  'Liked',
#  '\n13\n',
#  '13',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 18',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n6 retweets\n\n',
#  '\n6 retweets\n',
#  '6 retweets',
#  '\n\n11 likes\n\n',
#  '\n11 likes\n',
#  '11 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n6\n',
#  '6',
#  'Retweeted',
#  '\n6\n',
#  '6',
#  'Like',
#  '\n11\n',
#  '11',
#  'Liked',
#  '\n11\n',
#  '11',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 18',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n4 retweets\n\n',
#  '\n4 retweets\n',
#  '4 retweets',
#  '\n\n12 likes\n\n',
#  '\n12 likes\n',
#  '12 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n4\n',
#  '4',
#  'Retweeted',
#  '\n4\n',
#  '4',
#  'Like',
#  '\n12\n',
#  '12',
#  'Liked',
#  '\n12\n',
#  '12',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 18',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n14 likes\n\n',
#  '\n14 likes\n',
#  '14 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n14\n',
#  '14',
#  'Liked',
#  '\n14\n',
#  '14',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 15',
#  'More',
#  'https://',
#  'twitter.com/AstroStaab/sta',
#  'tus/1162103864608169984',
#  '\xa0…',
#  '\xa0',
#  '\xa0',
#  '@AstroStaab',
#  '@airandspace',
#  'pic.twitter.com/lupkv6AQMn',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n4 retweets\n\n',
#  '\n4 retweets\n',
#  '4 retweets',
#  '\n\n14 likes\n\n',
#  '\n14 likes\n',
#  '14 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n4\n',
#  '4',
#  'Retweeted',
#  '\n4\n',
#  '4',
#  'Like',
#  '\n14\n',
#  '14',
#  'Liked',
#  '\n14\n',
#  '14',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 15',
#  'More',
#  '\n\n1 reply\n\n',
#  '\n1 reply\n',
#  '1 reply',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n16 likes\n\n',
#  '\n16 likes\n',
#  '16 likes',
#  'Reply',
#  '\n1\n',
#  '1',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n16\n',
#  '16',
#  'Liked',
#  '\n16\n',
#  '16',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 15',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n11 retweets\n\n',
#  '\n11 retweets\n',
#  '11 retweets',
#  '\n\n16 likes\n\n',
#  '\n16 likes\n',
#  '16 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n11\n',
#  '11',
#  'Retweeted',
#  '\n11\n',
#  '11',
#  'Like',
#  '\n16\n',
#  '16',
#  'Liked',
#  '\n16\n',
#  '16',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 14',
#  'More',
#  '\n\n2 replies\n\n',
#  '\n2 replies\n',
#  '2 replies',
#  '\n\n7 retweets\n\n',
#  '\n7 retweets\n',
#  '7 retweets',
#  '\n\n29 likes\n\n',
#  '\n29 likes\n',
#  '29 likes',
#  'Reply',
#  '\n2\n',
#  '2',
#  'Retweet',
#  '\n7\n',
#  '7',
#  'Retweeted',
#  '\n7\n',
#  '7',
#  'Like',
#  '\n29\n',
#  '29',
#  'Liked',
#  '\n29\n',
#  '29',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 13',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n20 likes\n\n',
#  '\n20 likes\n',
#  '20 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n20\n',
#  '20',
#  'Liked',
#  '\n20\n',
#  '20',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 12',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n11 retweets\n\n',
#  '\n11 retweets\n',
#  '11 retweets',
#  '\n\n14 likes\n\n',
#  '\n14 likes\n',
#  '14 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n11\n',
#  '11',
#  'Retweeted',
#  '\n11\n',
#  '11',
#  'Like',
#  '\n14\n',
#  '14',
#  'Liked',
#  '\n14\n',
#  '14',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 10',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n17 likes\n\n',
#  '\n17 likes\n',
#  '17 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n17\n',
#  '17',
#  'Liked',
#  '\n17\n',
#  '17',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 10',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n6 retweets\n\n',
#  '\n6 retweets\n',
#  '6 retweets',
#  '\n\n18 likes\n\n',
#  '\n18 likes\n',
#  '18 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n6\n',
#  '6',
#  'Retweeted',
#  '\n6\n',
#  '6',
#  'Like',
#  '\n18\n',
#  '18',
#  'Liked',
#  '\n18\n',
#  '18',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 10',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n7 retweets\n\n',
#  '\n7 retweets\n',
#  '7 retweets',
#  '\n\n25 likes\n\n',
#  '\n25 likes\n',
#  '25 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n7\n',
#  '7',
#  'Retweeted',
#  '\n7\n',
#  '7',
#  'Like',
#  '\n25\n',
#  '25',
#  'Liked',
#  '\n25\n',
#  '25',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 9',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n6 retweets\n\n',
#  '\n6 retweets\n',
#  '6 retweets',
#  '\n\n16 likes\n\n',
#  '\n16 likes\n',
#  '16 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n6\n',
#  '6',
#  'Retweeted',
#  '\n6\n',
#  '6',
#  'Like',
#  '\n16\n',
#  '16',
#  'Liked',
#  '\n16\n',
#  '16',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 7',
#  'More',
#  '\n\n1 reply\n\n',
#  '\n1 reply\n',
#  '1 reply',
#  '\n\n5 retweets\n\n',
#  '\n5 retweets\n',
#  '5 retweets',
#  '\n\n11 likes\n\n',
#  '\n11 likes\n',
#  '11 likes',
#  'Reply',
#  '\n1\n',
#  '1',
#  'Retweet',
#  '\n5\n',
#  '5',
#  'Retweeted',
#  '\n5\n',
#  '5',
#  'Like',
#  '\n11\n',
#  '11',
#  'Liked',
#  '\n11\n',
#  '11',
#  'Undo',
#  'Undo',
#  '\nMars Weather\u200f\xa0',
#  '\u200f',
#  '\xa0',
#  '@MarsWxReport',
#  'Aug 7',
#  'More',
#  '\n\n0 replies\n\n',
#  '\n0 replies\n',
#  '0 replies',
#  '\n\n4 retweets\n\n',
#  '\n4 retweets\n',
#  '4 retweets',
#  '\n\n9 likes\n\n',
#  '\n9 likes\n',
#  '9 likes',
#  'Reply',
#  '\n\n',
#  'Retweet',
#  '\n4\n',
#  '4',
#  'Retweeted',
#  '\n4\n',
#  '4',
#  'Like',
#  '\n9\n',
#  '9',
#  'Liked',
#  '\n9\n',
#  '9',
#  'Undo',
#  'Undo',
#  '\nClose\n',
#  'Close',
#  'Dismiss',
#  '\nClose\n',
#  'Close',
#  '\n\n\n            Previous\n          \n\n',
#  '\n\n            Previous\n          \n',
#  '\n            Previous\n          ',
#  '\n\n\n            Next\n          \n\n',
#  '\n\n            Next\n          \n',
#  '\n            Next\n          ',
#  '\nClose\n',
#  'Close',
#  'In this conversation',
#  '\nVerified accountProtected Tweets\xa0@\n',
#  'Verified accountProtected Tweets',
#  'Verified account',
#  'Verified account',
#  'Protected Tweets',
#  'Protected Tweets',
#  '\xa0',
#  '@',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  'Under 100 characters, optional',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  'Remember me',
#  '·',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  '\nClose\n',
#  'Close',
#  'Next Tweet from user']

# %%
<span class="css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0">InSight sol 261 (2019-08-21) low -102.4ºC (-152.4ºF) high -26.6ºC (-15.8ºF)
winds from the SSE at 4.9 m/s (11.0 mph) gusting to 16.0 m/s (35.8 mph)
pressure at 7.70 hPa</span>

# %%
pattern = re.compile("url\('(.*)'\)")

# %%
pattern.search("background-image: url('/spaceimages/images/wallpaper/PIA18903-1920x1200.jpg')").groups()[0]
# Out:
# '/spaceimages/images/wallpaper/PIA18903-1920x1200.jpg'

# %%
new_result
# Out:
# [<article alt="Galactic Gathering Gives Impressive Light Display" class="carousel_item" style="background-image: url('/spaceimages/images/wallpaper/PIA18903-1920x1200.jpg');">
#  <div class="default floating_text_area ms-layer">
#  <h2 class="category_title">
#  </h2>
#  <h2 class="brand_title">
#  				  FEATURED IMAGE
#  				</h2>
#  <h1 class="media_feature_title">
#  				  Galactic Gathering Gives Impressive Light Display				</h1>
#  <div class="description">
#  </div>
#  <footer>
#  <a class="button fancybox" data-description="This composite image of NGC 2207 and IC 2163 contains data from Chandra, NASA's Hubble Space Telescope and the Spitzer Space Telescope." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA18903_ip.jpg" data-link="/spaceimages/details.php?id=PIA18903" data-title="Galactic Gathering Gives Impressive Light Display" id="full_image">
#  					FULL IMAGE
#  				  </a>
#  </footer>
#  </div>
#  <div class="gradient_container_top"></div>
#  <div class="gradient_container_bottom"></div>
#  </article>]

# %% [markdown]
# # This is the solution

# %%
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL of page to be scraped
url_2 = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"

# %%
# Retrieve page with the requests module
response = requests.get(url_2)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
#print(soup.prettify())

# %%
# div_class = soup.find("div class='article_teaser_body'")
# news_p = div_class.find("img")

# %%
# find_date = div_class.find('img').text

# %%
# print(div_class)

# %%
# results are returned as an iterable list
# results = soup.find_all('li', class_="result-row")

# %%
# # Loop through returned results
# for result in results:
#     # Error handling
#     try:
#         # Identify and return title of listing
#         title = result.find('a', class_="result-title").text
#         # Identify and return price of listing
#         price = result.a.span.text
#         # Identify and return link to listing
#         link = result.a['href']

#         # Print results only if title, price, and link are available
#         if (title and price and link):
#             print('-------------')
#             print(title)
#             print(price)
#             print(link)
#     except AttributeError as e:
#         print(e)
